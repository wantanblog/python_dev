# %%
# インポートセット
from keras.datasets import mnist
import numpy as npy
from keras.utils import np_utils
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# データの読み出し
mnist_raw_data = npy.load('mnist_raw.npz')

x_train=mnist_raw_data['x_train']
y_train=mnist_raw_data['y_train']
x_test=mnist_raw_data['x_test']
y_test=mnist_raw_data['y_test']

# %%
#データ整形
from keras.utils import np_utils

# 28×28のまま扱う
x_train=x_train.reshape(60000,28,28,1)
# 0-255⇒0-1に変換
x_train=x_train.astype('float32')
x_train=x_train/255
# 1-of-K符号化法で表現
num_classes=10
y_train=np_utils.to_categorical(y_train,num_classes)

x_test=x_test.reshape(10000,28,28,1)
x_test=x_test.astype('float32')
x_test=x_test/255
y_test=np_utils.to_categorical(y_test,num_classes)

# %%
# CNNモデルの実装（プーリングの追加）
npy.random.seed
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.optimizers import Adam
import time

model = Sequential()
model.add(Conv2D(16,(3,3), input_shape=(28,28,1),activation='relu'))
model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=Adam(),metrics=['accuracy'])

startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000, epochs=20,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:3f}sec".format(time.time() - startTime))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 30s 492ms/step - loss: 0.7492 - accuracy: 0.8193 - val_loss: 0.1983 - val_accuracy: 0.9420
# Epoch 2/20
# 60/60 [==============================] - 30s 503ms/step - loss: 0.1505 - accuracy: 0.9561 - val_loss: 0.1050 - val_accuracy: 0.9678
# Epoch 3/20
# 60/60 [==============================] - 32s 531ms/step - loss: 0.0934 - accuracy: 0.9724 - val_loss: 0.0648 - val_accuracy: 0.9798
# Epoch 4/20
# 60/60 [==============================] - 32s 539ms/step - loss: 0.0704 - accuracy: 0.9793 - val_loss: 0.0524 - val_accuracy: 0.9833
# Epoch 5/20
# 60/60 [==============================] - 34s 560ms/step - loss: 0.0582 - accuracy: 0.9824 - val_loss: 0.0460 - val_accuracy: 0.9852
# Epoch 6/20
# 60/60 [==============================] - 30s 505ms/step - loss: 0.0492 - accuracy: 0.9849 - val_loss: 0.0414 - val_accuracy: 0.9873
# Epoch 7/20
# 60/60 [==============================] - 30s 500ms/step - loss: 0.0442 - accuracy: 0.9866 - val_loss: 0.0377 - val_accuracy: 0.9873
# Epoch 8/20
# 60/60 [==============================] - 30s 499ms/step - loss: 0.0381 - accuracy: 0.9883 - val_loss: 0.0367 - val_accuracy: 0.9880
# Epoch 9/20
# 60/60 [==============================] - 30s 499ms/step - loss: 0.0361 - accuracy: 0.9890 - val_loss: 0.0385 - val_accuracy: 0.9864
# Epoch 10/20
# 60/60 [==============================] - 30s 500ms/step - loss: 0.0327 - accuracy: 0.9904 - val_loss: 0.0316 - val_accuracy: 0.9892
# Epoch 11/20
# 60/60 [==============================] - 30s 499ms/step - loss: 0.0295 - accuracy: 0.9911 - val_loss: 0.0345 - val_accuracy: 0.9882
# Epoch 12/20
# 60/60 [==============================] - 30s 502ms/step - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.0299 - val_accuracy: 0.9901
# Epoch 13/20
# 60/60 [==============================] - 30s 498ms/step - loss: 0.0241 - accuracy: 0.9927 - val_loss: 0.0321 - val_accuracy: 0.9894
# Epoch 14/20
# 60/60 [==============================] - 30s 496ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.0318 - val_accuracy: 0.9899
# Epoch 15/20
# 60/60 [==============================] - 30s 497ms/step - loss: 0.0208 - accuracy: 0.9938 - val_loss: 0.0303 - val_accuracy: 0.9903
# Epoch 16/20
# 60/60 [==============================] - 30s 500ms/step - loss: 0.0194 - accuracy: 0.9939 - val_loss: 0.0315 - val_accuracy: 0.9896
# Epoch 17/20
# 60/60 [==============================] - 30s 498ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.0305 - val_accuracy: 0.9906
# Epoch 18/20
# 60/60 [==============================] - 30s 495ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0317 - val_accuracy: 0.9903
# Epoch 19/20
# 60/60 [==============================] - 30s 496ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0326 - val_accuracy: 0.9906
# Epoch 20/20
# 60/60 [==============================] - 30s 500ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.0326 - val_accuracy: 0.9901
# Test loss: 0.03263436257839203
# Test accuracy: 0.9901000261306763
# Computation time:618.290401sec

# %%
# CNNモデルの実装（ドロップアウトの追加）
npy.random.seed
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.optimizers import Adam
import time

model = Sequential()
model.add(Conv2D(16,(3,3), input_shape=(28,28,1),activation='relu'))
model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=Adam(),metrics=['accuracy'])

startTime = time.time()
history = model.fit(x_train,y_train,batch_size=1000, epochs=20,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
print("Computation time:{0:3f}sec".format(time.time() - startTime))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 20s 336ms/step - loss: 0.8209 - accuracy: 0.7477 - val_loss: 0.1750 - val_accuracy: 0.9481
# Epoch 2/20
# 60/60 [==============================] - 21s 349ms/step - loss: 0.1665 - accuracy: 0.9501 - val_loss: 0.0742 - val_accuracy: 0.9769
# Epoch 3/20
# 60/60 [==============================] - 21s 351ms/step - loss: 0.1007 - accuracy: 0.9697 - val_loss: 0.0491 - val_accuracy: 0.9840
# Epoch 4/20
# 60/60 [==============================] - 22s 370ms/step - loss: 0.0734 - accuracy: 0.9785 - val_loss: 0.0422 - val_accuracy: 0.9863
# Epoch 5/20
# 60/60 [==============================] - 22s 374ms/step - loss: 0.0596 - accuracy: 0.9819 - val_loss: 0.0358 - val_accuracy: 0.9884
# Epoch 6/20
# 60/60 [==============================] - 21s 358ms/step - loss: 0.0543 - accuracy: 0.9832 - val_loss: 0.0290 - val_accuracy: 0.9906
# Epoch 7/20
# 60/60 [==============================] - 23s 379ms/step - loss: 0.0451 - accuracy: 0.9857 - val_loss: 0.0277 - val_accuracy: 0.9913
# Epoch 8/20
# 60/60 [==============================] - 22s 373ms/step - loss: 0.0410 - accuracy: 0.9875 - val_loss: 0.0264 - val_accuracy: 0.9916
# Epoch 9/20
# 60/60 [==============================] - 23s 377ms/step - loss: 0.0364 - accuracy: 0.9887 - val_loss: 0.0246 - val_accuracy: 0.9917
# Epoch 10/20
# 60/60 [==============================] - 22s 370ms/step - loss: 0.0335 - accuracy: 0.9897 - val_loss: 0.0234 - val_accuracy: 0.9917
# Epoch 11/20
# 60/60 [==============================] - 22s 362ms/step - loss: 0.0294 - accuracy: 0.9910 - val_loss: 0.0239 - val_accuracy: 0.9916
# Epoch 12/20
# 60/60 [==============================] - 21s 357ms/step - loss: 0.0293 - accuracy: 0.9908 - val_loss: 0.0213 - val_accuracy: 0.9932
# Epoch 13/20
# 60/60 [==============================] - 21s 350ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.0212 - val_accuracy: 0.9931
# Epoch 14/20
# 60/60 [==============================] - 21s 353ms/step - loss: 0.0241 - accuracy: 0.9923 - val_loss: 0.0246 - val_accuracy: 0.9926
# Epoch 15/20
# 60/60 [==============================] - 21s 351ms/step - loss: 0.0227 - accuracy: 0.9928 - val_loss: 0.0197 - val_accuracy: 0.9936
# Epoch 16/20
# 60/60 [==============================] - 20s 334ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.0200 - val_accuracy: 0.9930
# Epoch 17/20
# 60/60 [==============================] - 20s 335ms/step - loss: 0.0197 - accuracy: 0.9938 - val_loss: 0.0195 - val_accuracy: 0.9934
# Epoch 18/20
# 60/60 [==============================] - 20s 333ms/step - loss: 0.0177 - accuracy: 0.9944 - val_loss: 0.0189 - val_accuracy: 0.9936
# Epoch 19/20
# 60/60 [==============================] - 20s 334ms/step - loss: 0.0170 - accuracy: 0.9947 - val_loss: 0.0195 - val_accuracy: 0.9938
# Epoch 20/20
# 60/60 [==============================] - 20s 340ms/step - loss: 0.0145 - accuracy: 0.9955 - val_loss: 0.0207 - val_accuracy: 0.9932
# Test loss: 0.020667586475610733
# Test accuracy: 0.9932000041007996
# Computation time:433.481964sec
